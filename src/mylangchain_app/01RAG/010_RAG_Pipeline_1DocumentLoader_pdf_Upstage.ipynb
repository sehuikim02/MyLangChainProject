# %% [markdown]
# ### 1) 라이브러리 설치

# %%
# poetry add pypdf=">=4.2.0,<5.0.0"
# poetry add langchain-upstage

# %% [markdown]
# #### PyPDFLoader 간단한 예제

# %%
from dotenv import load_dotenv
import os

# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

UPSTAGE_API_KEY = os.getenv("UPSTAGE_API_KEY")
print(UPSTAGE_API_KEY[30:])
# Out:
# H3

# %% [markdown]
# #### Upstage 를 사용한 RAG
# * ChatUpstage
# * UpstageEmbeddings
# * UpstageDocumentParseLoader

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_upstage import ChatUpstage
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain_upstage import UpstageEmbeddings

print("==> 1. 문서 로딩 → PDF 읽기...")
file_path = "../data/tutorial-korean.pdf"
loader = PyPDFLoader('../data/tutorial-korean.pdf')
documents = loader.load()
print(f"  총 {len(documents)}페이지 로드 완료")
# Out:
# ==> 1. 문서 로딩 → PDF 읽기...
#   총 39페이지 로드 완료

# %%
print("==> 2. 문서 분할 → 작은 청크로 나누기")
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,        # 청크 크기 (한국어 최적화)
    chunk_overlap=200,      # 중복 부분 (맥락 보존)
    separators=["\n\n", "\n", ".", " ", ""] # 자연스러운 분할을 위한 구분자
)

chunks = text_splitter.split_documents(documents)
print(f"  {len(chunks)}개 청크 생성 완료")
print(f"  평균 청크 길이: {sum(len(chunk.page_content) for chunk in chunks) / len(chunks):.0f}자")
print(type(chunks[0]))
# Out:
# ==> 2. 문서 분할 → 작은 청크로 나누기
#   66개 청크 생성 완료
#   평균 청크 길이: 688자
# <class 'langchain_core.documents.base.Document'>

# %%
print("==> 3. 벡터화 → 임베딩으로 변환")
embeddings = UpstageEmbeddings(model="solar-embedding-1-large")

print("==> 4. 저장 → FAISS 벡터스토어에 저장")
vectorstore = FAISS.from_documents(chunks, embeddings)
print(f" FAISS 벡터스토어 생성 완료 ({len(chunks)}개 벡터)")
# 로컬 파일로 저장
vectorstore.save_local("faiss_db")

print("===> 5. 검색 → 질문과 유사한 문서 찾기")
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 6}  # 상위 6개 관련 문서 검색
)
print(" Retriever 설정 완료")
# Out:
# ==> 3. 벡터화 → 임베딩으로 변환
# ==> 4. 저장 → FAISS 벡터스토어에 저장
#  FAISS 벡터스토어 생성 완료 (66개 벡터)
# ===> 5. 검색 → 질문과 유사한 문서 찾기
#  Retriever 설정 완료

# %%
print("===> 6. 생성 → LLM으로 답변 생성")
llm = ChatUpstage(
        model="solar-pro",
        base_url="https://api.upstage.ai/v1",
        temperature=0.5
    )
print(llm)
# Out:
# ===> 6. 생성 → LLM으로 답변 생성
# client=<openai.resources.chat.completions.completions.Completions object at 0x000001D87E310740> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001D84A6C71D0> model_name='solar-pro' temperature=0.5 model_kwargs={} upstage_api_key=SecretStr('**********') upstage_api_base='https://api.upstage.ai/v1'

# %%
# 한국어 최적화 프롬프트
prompt_template = """
당신은 BlueJ 프로그래밍 환경 전문가입니다. 
아래 문서 내용을 바탕으로 정확하고 친절한 답변을 제공해주세요.

문서 내용:
{context}

질문: {question}

답변 규칙:
1. 문서 내용만을 근거로 답변하세요
2. 단계별 설명이 필요하면 순서대로 작성하세요  
3. 구체적인 메뉴명, 버튼명을 포함하세요
4. 문서에 없는 정보는 "문서에서 찾을 수 없습니다"라고 하세요

답변:"""

prompt = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "question"]
)
print(" 프롬프트 설정 완료")
print(prompt)
# Out:
#  프롬프트 설정 완료
# input_variables=['context', 'question'] input_types={} partial_variables={} template='\n당신은 BlueJ 프로그래밍 환경 전문가입니다. \n아래 문서 내용을 바탕으로 정확하고 친절한 답변을 제공해주세요.\n\n문서 내용:\n{context}\n\n질문: {question}\n\n답변 규칙:\n1. 문서 내용만을 근거로 답변하세요\n2. 단계별 설명이 필요하면 순서대로 작성하세요  \n3. 구체적인 메뉴명, 버튼명을 포함하세요\n4. 문서에 없는 정보는 "문서에서 찾을 수 없습니다"라고 하세요\n\n답변:'

# %%
# ===================================
# 7. QA 체인 생성
# ===================================
print("\n ===> 7.  QA 체인 생성...")
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    chain_type_kwargs={"prompt": prompt},
    return_source_documents=True
)
print("  RAG 파이프라인 구축 완료!")

# ===================================
# 8. 테스트 질문들
# ===================================
test_questions = [
    "BlueJ에서 객체를 생성하는 방법은 무엇인가요?",
    "컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?", 
    "디버깅을 위해 중단점을 설정하는 방법을 알려주세요",
    "코드패드는 무엇이고 어떻게 사용하나요?",
    "애플릿을 만들고 실행하는 방법을 설명해주세요"
]

print("\n" + "=" * 60)
print(" RAG 시스템 테스트")
print("=" * 60)

# ===================================
# 9. 질문 및 답변 실행
# ===================================
for i, question in enumerate(test_questions, 1):
    print(f"\n【테스트 {i}/5】")
    print(f" 질문: {question}")
    print(" 답변 생성 중...")
    
    # RAG 실행
    result = qa_chain.invoke({"query": question})
    answer = result["result"]
    source_docs = result["source_documents"]
    
    print(f"\n 답변:")
    print("-" * 50)
    print(answer)
    
    # 참조 문서 정보
    print(f"\n 참조 문서:")
    for j, doc in enumerate(source_docs[:3], 1):
        page = doc.metadata.get('page', 'N/A')
        preview = doc.page_content[:80].replace('\n', ' ')
        print(f"   {j}. 페이지 {page}: {preview}...")
    
    print("\n" + "-" * 40)
# Out:
#  ===> 7.  QA 체인 생성...
#   RAG 파이프라인 구축 완료!
#
# ============================================================
#  RAG 시스템 테스트
# ============================================================
#
# 【테스트 1/5】
#  질문: BlueJ에서 객체를 생성하는 방법은 무엇인가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# BlueJ에서 객체를 생성하는 방법은 다음과 같습니다. 문서 내용을 근거로 단계별로 설명드립니다.
#
# ---
#
# ### **1. 라이브러리 클래스로부터 객체 생성하기**
# - **메뉴 경로**: `Tools - Use Libraries Class` 선택
# - **대화상자**:
#   - 패키지 이름을 포함한 완전한 클래스명 입력 (예: `java.lang.String`)
#   - 최근 사용된 클래스 목록이 텍스트 필드에 표시됨
# - **생성자/정적 메소드 호출**:
#   - 클래스명 입력 후 **Enter**를 누르면 생성자 및 정적 메소드 목록이 표시됨
#   - 원하는 생성자 또는 메소드를 선택하여 호출
#
# ---
#
# ### **2. 일반 클래스로부터 객체 생성하기**
# 1. **프로젝트 열기**:
#    - `Project - Open...` 메뉴에서 프로젝트 선택 (예: `examples/people`)
# 2. **클래스 아이콘 확인**:
#    - 메인 윈도우 중앙에 표시된 클래스 아이콘(예: `Person`, `Staff`) 확인
# 3. **객체 생성**:
#    - 클래스 아이콘에서 **마우스 오른쪽 클릭** (Mac: `Ctrl+Click`)
#    - 팝업 메뉴에서 **생성자 함수** 선택
#    - 객체 이름 입력 대화상자가 나타나면 기본 이름(예: `staff_1`) 사용 또는 직접 입력 후 **OK** 클릭
# 4. **생성된 객체 확인**:
#    - 생성된 객체는 **오브젝트 벤치(Object Bench)**에 표시됨 (그림 4 참조)
#
# ---
#
# ### **주의사항**
# - **추상 클래스**는 객체를 생성할 수 없음 (예: `Person` 클래스에 `<<abstract>>` 표시 시 생성 불가)
# - **정적 메소드**는 클래스 팝업 메뉴에서 직접 호출 가능 (예: `main` 메소드)
#
# ---
#
# ### **추가 기능**
# - **메소드 실행**:
#   - 오브젝트 벤치의 객체에서 **마우스 오른쪽 클릭** → 팝업 메뉴에서 실행할 메소드 선택
# - **애플릿 객체 생성**:
#   - 일반 클래스와 동일한 방법으로 생성 가능하나, **완전한 실행은 불가능** (테스트용 메소드 실행만 가능)
#
# 문서에는 중단점 설정이나 디버깅 관련 내용은 언급되지 않았습니다. (문서에서 찾을 수 없습니다)
#
#  참조 문서:
#    1. 페이지 1: 3.1. BlueJ 시작하기 ············································· ··················...
#    2. 페이지 35: 3610.6. 라이브러리 클래스로부터 객체생성하기 BlueJ 는 JDK에서 제공하는 라이브러리의 클래스들로부터 객체를 생성하기 위한 기능을  제...
#    3. 페이지 7: 83.2. 프로젝트 열기 프로젝트란, 관련 있는 여러개의 파일들을 묶어서 관리하기 위한 하나의 작업 단위를 말합니다.  BlueJ  프로젝트는 ...
#
# ----------------------------------------
#
# 【테스트 2/5】
#  질문: 컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# 문서 내용을 바탕으로 컴파일 오류 확인 방법을 단계별로 안내드립니다:
#
# 1. **에디터 창 확인**
#    - 컴파일 오류가 발생하면, 해당 에러가 발생한 소스 코드 위치를 보여주는 **에디터 창**이 자동으로 열립니다.
#    - 에러가 발생한 라인은 **반전 표시**되며, 에디터 하단의 **정보창(information area)**에 구체적인 에러 메시지가 출력됩니다.
#
# 2. **도움말 활용 (물음표 버튼)**
#    - 정보창 오른쪽의 **물음표(?) 아이콘**을 클릭하면, 해당 에러 메시지에 대한 추가 설명이 표시됩니다(문서 그림 8 참조).
#    - *단, 모든 에러에 도움말이 제공되는 것은 아닙니다.*
#
# 3. **프로젝트 컴파일 시 오류 처리**
#    - 여러 클래스를 수정한 후 **프로젝트 윈도우 툴바의 Compile 버튼**을 눌러 전체 프로젝트를 컴파일할 경우:
#      - 오류가 있는 클래스가 있으면 해당 클래스로 에디터가 이동하며, 정보창에 에러 메시지가 표시됩니다.
#
# 4. **체크 표시 확인**
#    - 수정된 클래스 아이콘에 **체크 표시**가 나타나는지 확인하세요. 체크 표시가 있는 클래스는 재컴파일이 필요함을 의미합니다.
#
# 5. **객체 벤치 상태**
#    - 컴파일 오류 발생 시 **오브젝트 벤치**에 생성된 객체가 모두 사라집니다. 이는 클래스 구현 변경 시 자동 초기화되기 때문입니다.
#
# 6. **저장 관련 참고 사항**
#    - 소스 코드는 자동으로 저장되므로 별도 저장이 필요 없지만, 시스템 불안정이 우려될 경우 **Class 메뉴**에서 수동으로 저장할 수 있습니다.
#
# > 문서에는 언급되지 않은 추가 기능(예: 특정 단축키)은 "문서에서 찾을 수 없습니다"로 답변드립니다.
#
#  참조 문서:
#    1. 페이지 12: 클래스를 성공적으로 컴파일 하였다면 에디터를 닫으십시오.  프로젝트 윈도우에 툴바 역시 Compile 버튼을 가지고 있습니다. 이 컴파일 기능은...
#    2. 페이지 12: 13  노트 : 프로젝트를 처음 열었을 때 왜 클래스 아이콘에 체크표시가 되어있지 않은지 궁금할 수 있습니다. people  프로젝트 내의 클래...
#    3. 페이지 1: 3.7. 컴파일러 에러들에 관한 도움말 ······································· ··················...
#
# ----------------------------------------
#
# 【테스트 3/5】
#  질문: 디버깅을 위해 중단점을 설정하는 방법을 알려주세요
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# **디버깅을 위해 중단점을 설정하는 방법**
#
# 1. **프로젝트 열기**
#    - `examples` 디렉토리에 포함된 `debugdemo` 프로젝트를 엽니다.
#
# 2. **소스 코드 편집기 접근**
#    - `Demo` 클래스를 열고, `loop` 메소드를 찾습니다.
#
# 3. **중단점 설정**
#    - `loop` 메소드 내 `for` 반복문 중 임의의 라인을 선택합니다.
#    - **편집기 왼쪽의 중단점 영역** (줄 번호 옆 빈 공간)을 **마우스 왼쪽 버튼으로 클릭**합니다.
#      - 작은 **stop 표시**가 나타나면 중단점이 설정된 것입니다.
#
# 4. **중단점 확인 및 실행**
#    - `Demo` 클래스에서 객체를 생성한 후, `loop(10)` 메소드를 호출하여 프로그램을 실행합니다.
#    - 중단점에 도달하면 프로그램 실행이 일시 중지되며, **디버거 윈도우**와 **현재 실행 라인**이 반전되어 표시됩니다.
#
# 5. **중단점 제거**
#    - 중단점을 제거하려면 동일한 중단점 영역을 다시 **마우스 왼쪽 버튼으로 클릭**하여 stop 표시를 제거합니다.
#
# > **참고**: 중단점은 코드 실행 흐름을 제어하여 변수 상태나 로직 오류를 분석하는 데 유용합니다. (문서 26~28p 참조)
#
#  참조 문서:
#    1. 페이지 25: 267. 디버깅 이 절에서는, BlueJ의 디버깅에 관한 기능들 중에서 가장 중요한 측면을 소개합니다. 컴퓨터  프로그래밍 담당 선생님들은 첫 ...
#    2. 페이지 2: 37. 디버깅 ························································· ··············...
#    3. 페이지 25: 마우스 왼쪽 버튼으로 클릭함으로써 중단점을 설정할 수 있습니다. 작은 stop 표시가 중단점을 의미합니다. 바로 시도해 봅시다. Demo  클래...
#
# ----------------------------------------
#
# 【테스트 4/5】
#  질문: 코드패드는 무엇이고 어떻게 사용하나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# **코드패드란?**
# BlueJ의 코드패드는 자바 코드(표현식 및 명령문)의 일부분을 실시간으로 평가하고 테스트할 수 있는 도구입니다. 프로그램의 동작을 조사하거나 특정 구문을 시험할 때 유용하며, 결과값과 타입, 오류 메시지를 즉시 확인할 수 있습니다.
#
# ---
#
# ### **코드패드 사용 방법 (단계별 설명)**
#
# #### **1. 코드패드 표시하기**
# - **메뉴 경로**: `보기 > 코드패드 보기(Show Code Pad)`
# - **위치**: 실행 후 메인 화면의 **오른쪽 하단**(오브젝트 벤치 옆)에 표시됩니다.
# - **크기 조절**: 코드패드와 오브젝트 벤치 사이의 가로/세로선을 드래그하여 조정 가능합니다.
#
# #### **2. 표현식 평가**
# - **입력 예시**:
#   ```java
#   4 + 45
#   "hello".length()
#   Math.max(33, 4)
#   new Student()  // 프로젝트 클래스 참조 가능
#   ```
# - **실행 방법**: 입력 후 **Enter 키**를 누르면 결과가 출력됩니다.
#   - 결과 형식: `값 (타입)` (예: `49 (int)`)
#   - 객체 생성 시: `<object reference> (클래스명)`과 함께 **작은 객체 아이콘**이 표시됩니다.
#
# #### **3. 명령문 실행**
# - **단일 라인 명령문**:
#   ```java
#   System.out.println("Hello");
#   ```
# - **멀티라인 명령문**:
#   1. 첫 라인 입력 후 **Shift + Enter**로 줄 바꿈.
#   2. 예시:
#      ```java
#      int sum = 10;
#      sum += 5;
#      System.out.println(sum);  // Enter로 실행
#      ```
#   - **주의**: 지역 변수는 동일 라인 내에서만 유효합니다. 다른 라인에서 참조 불가능.
#
# #### **4. 객체 관리**
# - **오브젝트 벤치로 이동**:
#   코드패드의 **객체 아이콘**을 드래그하여 오브젝트 벤치에 놓습니다.
#   - 이후 팝업 메뉴나 코드패드에서 해당 객체의 메소드를 호출할 수 있습니다.
# - **객체 검사**:
#   코드패드의 객체 아이콘을 **더블클릭**하면 객체 상태 검사 화면이 열립니다.
#
# #### **5. 입력 이력 활용**
# - **상/하 화살표 키**로 이전 입력 내용을 재사용하거나 수정할 수 있습니다.
#
# #### **6. 주의사항**
# - 코드패드에서 **인스턴스 필드 정의**는 불가능합니다.
# - 오브젝트 벤치의 객체 필드만 참조하거나 메시지를 보낼 수 있습니다.
# - 멀티라인 입력 시 지역 변수는 각 라인마다 독립적으로 처리됩니다.
#
# ---
#
# ### **요약**
# - **코드패드**는 자바 코드의 빠른 테스트와 디버깅을 지원합니다.
# - **표현식 평가**, **명령문 실행**, **객체 생성/검사** 기능을 제공합니다.
# - 오브젝트 벤치와 연동해 객체를 관리하며, 입력 이력으로 효율성을 높일 수 있습니다.
#
# > 문서에서 명시되지 않은 기능(예: 코드패드 저장 기능)은 "문서에서 찾을 수 없습니다"로 답변합니다.
#
#  참조 문서:
#    1. 페이지 1: 5.2. 클래스 만들기 ················································ ··················...
#    2. 페이지 20: 216. 코드패드의 사용 BlueJ 코드패드는 자바 코드(표현식과 명령문)의 일부분을 쉽고 빠르게 평가할 수 있는 기능을  제공합니다. 따라서,...
#    3. 페이지 36: 15. 코드패드로부터 객체를 오브젝트 벤치로 이동하기 위해서는 객체아이콘을 드래그 하십시오. 16. 코드패드에서 생성된 객체를 검사하기 위해서는...
#
# ----------------------------------------
#
# 【테스트 5/5】
#  질문: 애플릿을 만들고 실행하는 방법을 설명해주세요
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### BlueJ에서 애플릿 만들기 및 실행 방법 (문서 내용 기반)
#
# ---
#
# #### **1. 애플릿 만들기**
# 1. **새 클래스 생성**
#    - BlueJ 메뉴에서 **"New Class"** 버튼을 클릭합니다.
#    - 대화상자에서 **클래스 유형**으로 **"Applet"**을 선택합니다.
#    - 클래스 이름을 입력하고 확인을 클릭합니다.
#      → 기본 애플릿 골격 코드가 자동 생성됩니다 (예: `paint` 메서드 포함).
#
# 2. **코드 편집**
#    - 생성된 클래스를 더블클릭하여 에디터를 엽니다.
#    - 샘플 코드는 주로 `paint` 메서드에 포함되어 있습니다.
#    - 필요한 기능을 구현하기 위해 코드를 수정하거나 추가합니다.
#      *예시: `init()`, `start()`, `stop()`, `destroy()` 메서드 추가 가능*.
#
# ---
#
# #### **2. 애플릿 테스트하기 (BlueJ 내부)**
# 1. **객체 생성**
#    - 오브젝트 벤치에서 애플릿 클래스 아이콘을 마우스 오른쪽 버튼으로 클릭 후 **"New"**를 선택해 객체를 생성합니다.
#    - 팝업 메뉴에서 특정 메서드를 실행하여 테스트할 수 있습니다.
#      *주의: 애플릿 전체는 실행되지 않으며, 개별 메서드만 테스트 가능합니다*.
#
# 2. **디버깅 제한 사항**
#    - BlueJ에서 설정한 **중단점(Breakpoint)**은 애플릿 뷰어/브라우저에서 무시됩니다.
#      → 디버깅이 필요한 경우 **"AppletWindow" 클래스**를 별도로 사용해야 합니다.
#      *문서 33페이지 참조: AppletWindow는 BlueJ 홈페이지에서 다운로드 가능*.
#
# ---
#
# #### **3. 애플릿 실행하기**
# 1. **Run Applet 실행**
#    - 컴파일 후, 애플릿 클래스 아이콘을 마우스 오른쪽 버튼으로 클릭 → **"Run Applet"** 선택.
#    - 대화상자에서 실행 방식을 선택합니다:
#      - **"Applet Viewer"**: JDK 내장 뷰어 사용 (권장, 버전 충돌 방지).
#      - **"Web Browser"**: 기본 브라우저 사용 (Windows/Mac).
#      - **"Generate HTML"**: 웹페이지만 생성.
#    - **"OK"**를 클릭하면 애플릿이 실행됩니다.
#
# 2. **예제 프로젝트 활용**
#    - 문서 32페이지 참조:
#      - `examples/appletdemo` 프로젝트를 열고 `CaseConverter` 애플릿을 실행해 볼 수 있습니다.
#      - 애플릿 뷰어는 JDK와 동일한 버전의 JVM을 사용해 안정성이 높습니다.
#
# ---
#
# #### **4. 주의사항**
# - **디버깅**:
#   - 애플릿 뷰어/브라우저에서 중단점이 작동하지 않음 → **AppletWindow** 클래스 필요.
# - **브라우저 호환성**:
#   - 일부 브라우저는 자바 버전과 충돌할 수 있으므로, **Applet Viewer** 사용을 권장합니다.
#
# ---
#
# ### 요약
# 1. **만들기**: New Class → Applet 선택 → 코드 편집.
# 2. **테스트**: 오브젝트 벤치에서 객체 생성 → 개별 메서드 실행.
# 3. **실행**: Run Applet → Applet Viewer/Web Browser 선택.
# 4. **디버깅**: AppletWindow 클래스 필요 (문서 33페이지).
#
# > 문서에 명시되지 않은 내용은 답변에서 제외되었습니다.
#
#  참조 문서:
#    1. 페이지 32: 33마이크로소프트 윈도우즈나 MAC OS시스템에서, BlueJ 는 여러분의 기본 브라우저를 사용 합니다. 유닉스 시스템의 경우는, BlueJ 설...
#    2. 페이지 31: 329. 애플릿 만들기 9.1. 애플릿 실행하기     BuleJ 는 어플리케이션 뿐만 아니라 애플릿을 만들고, 실행할 수 있습니다. 예제(ex...
#    3. 페이지 2: 8. 독립형 어플리케이션 생성 ··············································· ···············...
#
# ----------------------------------------

# %%
from langchain_upstage import UpstageGroundednessCheck

groundedness_check = UpstageGroundednessCheck()

# Grounded
# question = "BlueJ에서 객체를 생성하는 방법은 무엇인가요?"

# notGrounded
question = "현재 기온은 몇 도 인가요?"

retrieved_docs = retriever.invoke(question)
context = "\n\n".join([doc.page_content for doc in retrieved_docs])
#print(context)

response = llm.invoke(f"{question} 관련 정보: {context}")

request_input = {
    "context": context,
    "answer": response.content
}

response = groundedness_check.invoke(request_input)
print(response)
# Out:
# notGrounded
